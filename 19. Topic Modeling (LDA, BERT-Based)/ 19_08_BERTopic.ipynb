# %% [markdown]
# <a href="https://colab.research.google.com/github/LaJeremi/Tensorflow-nlp-tutorial-Practice-/blob/main/19.%20Topic%20Modeling%20(LDA%2C%20BERT-Based)/%2019_08_BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 19-08 버토픽(BERTopic)
#
#
# 출처: https://wikidocs.net/162076
#
# # 1. BERTopic
#
# 1) 텍스트 데이터를 SBERT로 임베딩합니다.
# 2) 문서를 군집화합니다.
# 3) 토픽 표현을 생성
#
# # 2. 데이터 로드

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 KB 6.8 MB/s eta 0:00:00
# WARNING: bertopic 0.14.0 does not provide the extra 'visualization'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 83.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 116.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 464.7 kB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
# 상위 5개의 샘플 출력
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
# ...

# %%
print('총 문서의 수 :', len(docs))
# Out:
# 총 문서의 수 : 18846

# %% [markdown]
# # 3. 토픽 모델링

# %%
model = BERTopic()
topics, probabilities = model.fit_transform(docs)

# %%
print('각 문서의 토픽 번호 리스트 :',len(topics))
print('첫번째 문서의 토픽 번호 :', topics[0])
# Out:
# 각 문서의 토픽 번호 리스트 : 18846
# 첫번째 문서의 토픽 번호 : 0

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                              Name
# 0       -1   6728                                  -1_to_and_the_of
# 1        0   1841                              0_game_team_games_he
# 2        1    591                     1_key_clipper_chip_encryption
# 3        2    526                              2_ites_cheek_yep_huh
# 4        3    471                        3_israel_israeli_jews_arab
# ..     ...    ...                                               ...
# 213    212     11          212_magi_zoroastrians_zoroastrian_osiris
# 214    213     10  213_manhattan_beauchaine_bobbeviceicotekcom_sank
# 215    214     10                214_keycode_xtermmap_definekey_key
# 216    215     10                  215_vote_publishing_cdrom_topics
# 217    216     10                216_software_level_wingert_shuttle
#
# [218 rows x 3 columns]

# %%
model.get_topic_info()['Count'].sum()
# Out:
# 18846

# %%
model.get_topic(5)
# Out:
# [('ram', 0.013850390283397596),
#  ('sale', 0.013387054530678934),
#  ('price', 0.01326922066582692),
#  ('drive', 0.012401682434370924),
#  ('meg', 0.011458506828672829),
#  ('shipping', 0.010879084468746128),
#  ('card', 0.01027811252331156),
#  ('monitor', 0.010118167678847623),
#  ('system', 0.009769743392205245),
#  ('motherboard', 0.00952331218050789)]

# %% [markdown]
# # 4. 토픽 시각화

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 5. 단어 시각화

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 6. 토픽 유사도 시각화

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 7. 토픽의 수 정하기

# %%
model = BERTopic(nr_topics=20)
topics, probabilities = model.fit_transform(docs)

# %%
model = BERTopic(nr_topics="auto")
topics, probabilities = model.fit_transform(docs)

# %%
# 각 토픽의 크기와 각 토픽에 할당된 단어들
model.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1   6462                                   -1_the_to_of_and
# 1        0   1817                               0_game_team_he_games
# 2        1    716                            1_image_jpeg_drive_file
# 3        2    715                      2_key_encryption_clipper_chip
# 4        3    603                             3_bike_car_engine_cars
# ..     ...    ...                                                ...
# 138    137     10                           137_ear_wax_ears_syringe
# 139    138     10            138_copyrighted_newspaper_article_buggy
# 140    139     10                       139_taste_sauce_recipe_gyros
# 141    140     10  140_18084tmibmclmsuedu_5173552178_mcwilliams_3...
# 142    141     10                     141_icon_icons_digitiser_click
#
# [143 rows x 3 columns]

# %% [markdown]
# # 8. 임의의 문서에 대한 예측

# %%
new_doc = docs[0]
print(new_doc)
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a lot of
# fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final
# regular season game.          PENS RULE!!!

# %%
topics, probs = model.transform([new_doc])
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %%
print('예측한 토픽 번호 :', topics)
# Out:
# 예측한 토픽 번호 : [0]

# %% [markdown]
# # 9. 모델 저장과 로드

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
