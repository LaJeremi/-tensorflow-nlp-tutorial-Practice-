# %% [markdown]
# # 09-10 Embedding Visualization (임베딩 벡터의 시각화)

# %% [markdown]
# # 1. 워드 임베딩 모델로부터 2개의 tsv 파일 생성하기
#
#
# 출처: https://wikidocs.net/50704

# %%
# !python -m gensim.scripts.word2vec2tensor --input eng_w2v --output eng_w2v
# Out:
# 2023-02-14 23:44:45,635 - word2vec2tensor - INFO - running C:\Users\USER\anaconda3\envs\la1\lib\site-packages\gensim\scripts\word2vec2tensor.py --input eng_w2v --output eng_w2v
# 2023-02-14 23:44:45,635 - utils_any2vec - INFO - loading projection weights from eng_w2v
# 2023-02-14 23:44:47,146 - utils_any2vec - INFO - loaded (21613, 100) matrix from eng_w2v
# 2023-02-14 23:44:48,754 - word2vec2tensor - INFO - 2D tensor file saved to eng_w2v_tensor.tsv
# 2023-02-14 23:44:48,754 - word2vec2tensor - INFO - Tensor metadata file saved to eng_w2v_metadata.tsv
# 2023-02-14 23:44:48,754 - word2vec2tensor - INFO - finished running word2vec2tensor.py

# %% [markdown]
# # 2. 임베딩 프로젝터를 사용하여 시각화하기
#
# 구글의 임베딩 프로젝터를 사용해서 워드 임베딩 모델을 시각화해보겠습니다. 아래의 링크에 접속합니다.
#
# 링크 : https://projector.tensorflow.org/

# %%
from IPython.display import Image

# %%
Image("image/09-10 Embedding Visualization (bank).png")

# %%
Image("image/09-10 Embedding Visualization (man).png")
